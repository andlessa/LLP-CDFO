# %%
import pandas as pd

# %%
recast_2018 = pd.read_pickle('./pp2BB1j_2018_13.pcl')
recast_2016 = pd.read_pickle('./pp2BB1j_2016_08.pcl')
# recast_monojet = pd.read_pickle()

# %%
recast_2016.T
# Out:
#                                     0                    1                 2  \
# Luminosity (1/fb)                32.8                 32.8              32.8
# $N_s$                           8.377               0.5373               0.0
# AccEff                       0.000665             0.000043               0.0
# Total                  (12590.0, 1.0)       (12580.0, 1.0)    (12590.0, 1.0)
# Jet+MET selection    (935.5, 0.07431)     (726.6, 0.05776)  (679.1, 0.05393)
# DV selection       (8.377, 0.0006654)  (0.5373, 4.272e-05)        (0.0, 0.0)
# mLLP                            500.0                500.0             500.0
# mLSP                            450.0                475.0             485.0
# width                             0.0                  0.0               0.0
# tau_ns                           0.01                 0.01              0.01
# Total MC Events                 17778                17762             17783
# ...

# %%
recast_2018.T
# Out:
#                                   0                    1               2  \
# Luminosity (1/fb)             139.0                139.0           139.0
# SR                           HighPT            Trackless          HighPT
# $N_s$                           0.0               0.1844             0.0
# AccEff                          0.0             0.000003             0.0
# Total                (53350.0, 1.0)       (53350.0, 1.0)  (53300.0, 1.0)
# Jet selection      (12.0, 0.000225)    (105.0, 0.001969)      (0.0, 0.0)
# DV selection             (0.0, 0.0)  (0.1844, 3.456e-06)      (0.0, 0.0)
# mLLP                          500.0                500.0           500.0
# mLSP                          450.0                450.0           475.0
# width                           0.0                  0.0             0.0
# tau_ns                         0.01                 0.01            0.01
# Total MC Events               17778                17778           17762
# ...
